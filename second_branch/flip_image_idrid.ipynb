# %%
# Code pour dupliquer les images par flip et transferer quelques images test dans train dur le dataset IDRID

# %%
import os
import cv2
import shutil

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
! ls drive/'Shared drives'/'Datalab Wewyse'/Projets/'02. TeleOphtalmo '/'3. Models'/'2. Second_Branch'/mask_RCNN/data_train/
# Out:
# 'A. Segmentation'  'A. Segmentation (1)'

# %%
directory_image = 'drive/Shared drives/Datalab Wewyse/Projets/02. TeleOphtalmo /3. Models/2. Second_Branch/mask_RCNN/data_train/A. Segmentation/1. Original Images/a. Training Set/'
directory_image_aug = 'drive/Shared drives/Datalab Wewyse/Projets/02. TeleOphtalmo /3. Models/2. Second_Branch/mask_RCNN/data_train/A. Segmentation/1. Original Images/b. Testing Set/'

# %%
retinas = os.listdir(directory_image_aug)

# %%
# Move images in folder testing in training

# %%
remove_img = ['IDRiD_55.jpg', "IDRiD_61.jpg", "IDRiD_81.jpg"]

# %%
retinas = [retina for retina in retinas if retina not in remove_img]

# %%
[shutil.move(directory_image_aug+retina, directory_image+retina) for retina in retinas]
# Out:
# ['drive/Shared drives/Datalab Wewyse/Projets/02. TeleOphtalmo /3. Models/2. Second_Branch/mask_RCNN/data_train/A. Segmentation/1. Original Images/a. Training Set/IDRiD_80.jpg',
#  'drive/Shared drives/Datalab Wewyse/Projets/02. TeleOphtalmo /3. Models/2. Second_Branch/mask_RCNN/data_train/A. Segmentation/1. Original Images/a. Training Set/IDRiD_76.jpg',
#  'drive/Shared drives/Datalab Wewyse/Projets/02. TeleOphtalmo /3. Models/2. Second_Branch/mask_RCNN/data_train/A. Segmentation/1. Original Images/a. Training Set/IDRiD_79.jpg',
#  'drive/Shared drives/Datalab Wewyse/Projets/02. TeleOphtalmo /3. Models/2. Second_Branch/mask_RCNN/data_train/A. Segmentation/1. Original Images/a. Training Set/IDRiD_57.jpg',
#  'drive/Shared drives/Datalab Wewyse/Projets/02. TeleOphtalmo /3. Models/2. Second_Branch/mask_RCNN/data_train/A. Segmentation/1. Original Images/a. Training Set/IDRiD_58.jpg',
# ...

# %%
#list images
retinas = os.listdir(directory_image)

# %%
#read, flip and save new image
for retina in retinas:
    img = cv2.imread(directory_image+retina)
    img = cv2.flip(img, 1)
    save_name = retina[:-4]
    save_name = save_name + "_flip.jpg"
    cv2.imwrite(directory_image+save_name, img)

# %%
directory_mask = "drive/Shared drives/Datalab Wewyse/Projets/02. TeleOphtalmo /3. Models/2. Second_Branch/mask_RCNN/data_train/A. Segmentation/2. All Segmentation Groundtruths/a. Training Set/"
directory_mask_aug = 'drive/Shared drives/Datalab Wewyse/Projets/02. TeleOphtalmo /3. Models/2. Second_Branch/mask_RCNN/data_train/A. Segmentation/2. All Segmentation Groundtruths/b. Testing Set/'
pathologies = os.listdir(directory_mask)
pathologies_aug = os.listdir(directory_mask_aug)

# %%
# Move masks in folder testing in training

# %%
masks = []
for pathology in pathologies_aug:
    tmp_masks = os.listdir(directory_mask_aug+pathology)
    tmp_masks = [pathology + "/" + mask for mask in tmp_masks]
    masks += tmp_masks

# %%
remove_masks = ['IDRiD_55', "IDRiD_61", "IDRiD_81"]

# %%
remove_masks = [mask for mask in masks for remove in remove_masks if remove in mask]

# %%
masks = [mask for mask in masks if mask not in remove_masks]

# %%
[shutil.move(directory_mask_aug+mask,directory_mask+mask) for mask in masks]
# Out:
# ['drive/Shared drives/Datalab Wewyse/Projets/02. TeleOphtalmo /3. Models/2. Second_Branch/mask_RCNN/data_train/A. Segmentation/2. All Segmentation Groundtruths/a. Training Set/3. Hard Exudates/IDRiD_56_EX.tif',
#  'drive/Shared drives/Datalab Wewyse/Projets/02. TeleOphtalmo /3. Models/2. Second_Branch/mask_RCNN/data_train/A. Segmentation/2. All Segmentation Groundtruths/a. Training Set/3. Hard Exudates/IDRiD_60_EX.tif',
#  'drive/Shared drives/Datalab Wewyse/Projets/02. TeleOphtalmo /3. Models/2. Second_Branch/mask_RCNN/data_train/A. Segmentation/2. All Segmentation Groundtruths/a. Training Set/3. Hard Exudates/IDRiD_72_EX (1).tif',
#  'drive/Shared drives/Datalab Wewyse/Projets/02. TeleOphtalmo /3. Models/2. Second_Branch/mask_RCNN/data_train/A. Segmentation/2. All Segmentation Groundtruths/a. Training Set/3. Hard Exudates/IDRiD_76_EX.tif',
# ...

# %%
#create list for all masks (optic disc, exudates ...)
masks = []
for pathology in pathologies:
    tmp_masks = os.listdir(directory_mask+pathology)
    tmp_masks = [pathology + "/" + mask for mask in tmp_masks]
    masks += tmp_masks

# %%
#read, flip and save new mask
for mask in masks:
    img = cv2.imread(directory_mask+mask)
    img = cv2.flip(img, 1)
    save_name = mask[:-4]
    save_name = save_name + "_flip.tif"
    cv2.imwrite(directory_mask+save_name, img)
